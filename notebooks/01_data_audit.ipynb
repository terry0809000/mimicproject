# %% [markdown]
# # Notebook
# This notebook is a thin analysis layer; core pipeline logic lives in src/ and scripts/.

# %%
from src.utils.config import load_all_configs
cfg = load_all_configs('config')
cfg['project']
